# %% [markdown]
# ###Machine Learning with Spark: Tuning

# %% [markdown]
# ##### ML Pipelines API
#   * DataFrame &check;
#   * Transformer / Estimator / Pipeline &check;
#   * __CrossValidator / ParamGridBuilder / Evaluator__ &xlArr;

# %% [markdown]
# Extended example with the diamonds dataset, focusing on more elements of the ML process
# * Handling Categorical Variables
# * Evaluation
# * Tuning
# * Crossvalidation

# %%
spark.read.option("header", True).csv("/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv").printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: string (nullable = true)
# -- carat: string (nullable = true)
# -- cut: string (nullable = true)
# -- color: string (nullable = true)
# -- clarity: string (nullable = true)
# -- depth: string (nullable = true)
# -- table: string (nullable = true)
# -- price: string (nullable = true)
# -- x: string (nullable = true)
# -- y: string (nullable = true)
# -- z: string (nullable = true)
#
# </div>

# %%
data = spark.read.option("header", True).option("inferSchema", True) \
        .csv("/databricks-datasets/Rdatasets/data-001/csv/ggplot2/diamonds.csv")
  
data.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
# _c0|carat|      cut|color|clarity|depth|table|price|   x|   y|   z|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
#   1| 0.23|    Ideal|    E|    SI2| 61.5| 55.0|  326|3.95|3.98|2.43|
#   2| 0.21|  Premium|    E|    SI1| 59.8| 61.0|  326|3.89|3.84|2.31|
#   3| 0.23|     Good|    E|    VS1| 56.9| 65.0|  327|4.05|4.07|2.31|
#   4| 0.29|  Premium|    I|    VS2| 62.4| 58.0|  334| 4.2|4.23|2.63|
#   5| 0.31|     Good|    J|    SI2| 63.3| 58.0|  335|4.34|4.35|2.75|
#   6| 0.24|Very Good|    J|   VVS2| 62.8| 57.0|  336|3.94|3.96|2.48|
#   7| 0.24|Very Good|    I|   VVS1| 62.3| 57.0|  336|3.95|3.98|2.47|
#   8| 0.26|Very Good|    H|    SI1| 61.9| 55.0|  337|4.07|4.11|2.53|
#   9| 0.22|     Fair|    E|    VS2| 65.1| 61.0|  337|3.87|3.78|2.49|
#  10| 0.23|Very Good|    H|    VS1| 59.4| 61.0|  338| 4.0|4.05|2.39|
#  11|  0.3|     Good|    J|    SI1| 64.0| 55.0|  339|4.25|4.28|2.73|
#  12| 0.23|    Ideal|    J|    VS1| 62.8| 56.0|  340|3.93| 3.9|2.46|
#  13| 0.22|  Premium|    F|    SI1| 60.4| 61.0|  342|3.88|3.84|2.33|
#  14| 0.31|    Ideal|    J|    SI2| 62.2| 54.0|  344|4.35|4.37|2.71|
#  15|  0.2|  Premium|    E|    SI2| 60.2| 62.0|  345|3.79|3.75|2.27|
#  16| 0.32|  Premium|    E|     I1| 60.9| 58.0|  345|4.38|4.42|2.68|
#  17|  0.3|    Ideal|    I|    SI2| 62.0| 54.0|  348|4.31|4.34|2.68|
#  18|  0.3|     Good|    J|    SI1| 63.4| 54.0|  351|4.23|4.29| 2.7|
#  19|  0.3|     Good|    J|    SI1| 63.8| 56.0|  351|4.23|4.26|2.71|
#  20|  0.3|Very Good|    J|    SI1| 62.7| 59.0|  351|4.21|4.27|2.66|
# +---+-----+---------+-----+-------+-----+-----+-----+----+----+----+
# only showing top 20 rows
#
# </div>

# %%
data.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- _c0: integer (nullable = true)
# -- carat: double (nullable = true)
# -- cut: string (nullable = true)
# -- color: string (nullable = true)
# -- clarity: string (nullable = true)
# -- depth: double (nullable = true)
# -- table: double (nullable = true)
# -- price: integer (nullable = true)
# -- x: double (nullable = true)
# -- y: double (nullable = true)
# -- z: double (nullable = true)
#
# </div>

# %% [markdown]
# We'll look at the features in more detail ... but right away we see we'll have to do something about string-typed features.
#
# The price (label) is an integer, not a double. In many cases, an integer can be auto-widened to a double, but there may be some places we'll have to watch out.
#
# Also, that "\_c0" (a.k.a. the row number or row ID) ... not only is it not a feature, but it can leak irrelevant data:

# %%
display(data.select("_c0", "price").sample(False, 0.02, 42)) # what does this tell us? :)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_c0</th><th
0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>5139.0</td></tr><tr><td>1.14</td><td>Fair</td><td>G</td><td>VS1</td><td>57.5</td><td>67.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>6381.0</td></tr><tr><td>1.56</td><td>Ideal</td><td>G</td><td>VS2</td><td>62.2</td><td>54.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>12800.0</td></tr><tr><td>1.2</td><td>Premium</td><td>D</td><td>VVS1</td><td>62.1</td><td>59.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>15686.0</td></tr><tr><td>2.25</td><td>Premium</td><td>H</td><td>SI2</td><td>62.8</td><td>59.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>18034.0</td></tr><tr><td>0.71</td><td>Good</td><td>F</td><td>SI2</td><td>64.1</td><td>60.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2130.0</td></tr><tr><td>0.71</td><td>Good</td><td>F</td><td>SI2</td><td>64.1</td><td>60.0</td><td>0.0</td><td>0.0</td><td>0.0</td><td>2130.0</td></tr></tbody></table></div>

# %% [markdown]
# Looks like at least a few incomplete records in here

# %% [markdown]
# Now we need to do something about the categorical features: cut, color, and clarity.

# %%
data2.select("cut").distinct().show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------+
#       cut|
# +---------+
#   Premium|
#     Ideal|
#      Good|
#      Fair|
# Very Good|
# +---------+
#
# </div>

# %%
display(data2.groupBy("cut").count())
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cut</th><th>count</th></tr></thead><tbody><tr><td>Premium</td><td>13791</td></tr><tr><td>Ideal</td><td>21551</td></tr><tr><td>Good</td><td>4906</td></tr><tr><td>Fair</td><td>1610</td></tr><tr><td>Very Good</td><td>12082</td></tr></tbody></table></div>

# %% [markdown]
# First, we need to convert the categorical values to numbers.
#
# We can do that with a StringIndexer
#
# * https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.feature.StringIndexer
#
# Then we need to one-hot encode
# * In the "old days" we would create several OneHotEncoder objects
# * Now we use OneHotEncoderEstimator https://spark.apache.org/docs/latest/api/python/pyspark.ml.html#pyspark.ml.feature.OneHotEncoderEstimator
#   * Proper pattern for Estimator
#   * Handles multiple columns at once (yea!)

# %% [markdown]
# Now let's automate this work a bit: we'll use functional collections to create our feature helpers, and a pipeline to wrap them

# %%
from pyspark.ml.feature import *
from pyspark.ml import Pipeline

categoricalFields = ["cut", "color", "clarity"]

indexers = [StringIndexer(inputCol=f, outputCol=f + "Index") for f in categoricalFields]

encoder = OneHotEncoderEstimator(inputCols=[f + "Index" for f in categoricalFields], outputCols=[f + "Vec" for f in categoricalFields])

pipeline = Pipeline(stages=indexers + [encoder])

model = pipeline.fit(data2)

model.transform(data2).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----+---------+-----+-------+-----+-----+----+----+----+-----+--------+----------+------------+-------------+-------------+-------------+
# carat|      cut|color|clarity|depth|table|   x|   y|   z|label|cutIndex|colorIndex|clarityIndex|       cutVec|     colorVec|   clarityVec|
# +-----+---------+-----+-------+-----+-----+----+----+----+-----+--------+----------+------------+-------------+-------------+-------------+
#  0.23|    Ideal|    E|    SI2| 61.5| 55.0|3.95|3.98|2.43|326.0|     0.0|       1.0|         2.0|(4,[0],[1.0])|(6,[1],[1.0])|(7,[2],[1.0])|
#  0.21|  Premium|    E|    SI1| 59.8| 61.0|3.89|3.84|2.31|326.0|     1.0|       1.0|         0.0|(4,[1],[1.0])|(6,[1],[1.0])|(7,[0],[1.0])|
#  0.23|     Good|    E|    VS1| 56.9| 65.0|4.05|4.07|2.31|327.0|     3.0|       1.0|         3.0|(4,[3],[1.0])|(6,[1],[1.0])|(7,[3],[1.0])|
------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# That looks pretty good. Next, we need to bring all of our features together into a single vector. We've seen a helper that does exactly that

# %%
assembler = VectorAssembler(inputCols=[f + "Vec" for f in categoricalFields] + 
                            ["carat", "depth", "table", "x", "y", "z"], outputCol="features")

Pipeline(stages=indexers + [encoder, assembler]).fit(data2).transform(data2).select("features").show(truncate=False)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------------------------------------------------------------------+
# features                                                                   |
# +---------------------------------------------------------------------------+
# (23,[0,5,12,17,18,19,20,21,22],[1.0,1.0,1.0,0.23,61.5,55.0,3.95,3.98,2.43])|
# (23,[1,5,10,17,18,19,20,21,22],[1.0,1.0,1.0,0.21,59.8,61.0,3.89,3.84,2.31])|
# (23,[3,5,13,17,18,19,20,21,22],[1.0,1.0,1.0,0.23,56.9,65.0,4.05,4.07,2.31])|
# (23,[1,9,11,17,18,19,20,21,22],[1.0,1.0,1.0,0.29,62.4,58.0,4.2,4.23,2.63]) |
# (23,[3,12,17,18,19,20,21,22],[1.0,1.0,0.31,63.3,58.0,4.34,4.35,2.75])      |
# (23,[2,14,17,18,19,20,21,22],[1.0,1.0,0.24,62.8,57.0,3.94,3.96,2.48])      |
# (23,[2,9,15,17,18,19,20,21,22],[1.0,1.0,1.0,0.24,62.3,57.0,3.95,3.98,2.47])|
# (23,[2,7,10,17,18,19,20,21,22],[1.0,1.0,1.0,0.26,61.9,55.0,4.07,4.11,2.53])|
# (23,[5,11,17,18,19,20,21,22],[1.0,1.0,0.22,65.1,61.0,3.87,3.78,2.49])      |
# (23,[2,7,13,17,18,19,20,21,22],[1.0,1.0,1.0,0.23,59.4,61.0,4.0,4.05,2.39]) |
# (23,[3,10,17,18,19,20,21,22],[1.0,1.0,0.3,64.0,55.0,4.25,4.28,2.73])       |
# (23,[0,13,17,18,19,20,21,22],[1.0,1.0,0.23,62.8,56.0,3.93,3.9,2.46])       |
# (23,[1,6,10,17,18,19,20,21,22],[1.0,1.0,1.0,0.22,60.4,61.0,3.88,3.84,2.33])|
# (23,[0,12,17,18,19,20,21,22],[1.0,1.0,0.31,62.2,54.0,4.35,4.37,2.71])      |
# (23,[1,5,12,17,18,19,20,21,22],[1.0,1.0,1.0,0.2,60.2,62.0,3.79,3.75,2.27]) |
# (23,[1,5,17,18,19,20,21,22],[1.0,1.0,0.32,60.9,58.0,4.38,4.42,2.68])       |
# (23,[0,9,12,17,18,19,20,21,22],[1.0,1.0,1.0,0.3,62.0,54.0,4.31,4.34,2.68]) |
# (23,[3,10,17,18,19,20,21,22],[1.0,1.0,0.3,63.4,54.0,4.23,4.29,2.7])        |
# (23,[3,10,17,18,19,20,21,22],[1.0,1.0,0.3,63.8,56.0,4.23,4.26,2.71])       |
# (23,[2,10,17,18,19,20,21,22],[1.0,1.0,0.3,62.7,59.0,4.21,4.27,2.66])       |
# +---------------------------------------------------------------------------+
# only showing top 20 rows
#
# </div>

# %% [markdown]
# Let's finish the pipeline by adding the Linear Regression algorithm

# %%
from pyspark.ml.regression import LinearRegression

lr = LinearRegression()
completePipeline = Pipeline(stages=indexers + [encoder, assembler, lr])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Now we're ready to train and do an initial test

# %%
train, test = data2.randomSplit([0.75, 0.25])

model = completePipeline.fit(train)

predictions = model.transform(test).select("label", "prediction")

display(predictions.sample(False, 0.05))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>label</th><th>prediction</th></tr></thead><tbody><tr><td
tr><td>462.0</td><td>-303.36075063008315</td></tr><tr><td>461.0</td><td>-928.0334375786208</td></tr><tr><td>862.0</td><td>1268.1355711084302</td></tr><tr><td>1018.0</td><td>1904.0509076752123</td></tr><tr><td>427.0</td><td>-820.1863547903379</td></tr><tr><td>702.0</td><td>784.6268298689106</td></tr><tr><td>900.0</td><td>735.2866081237228</td></tr><tr><td>1020.0</td><td>1462.1525353416114</td></tr><tr><td>929.0</td><td>1810.7399141100266</td></tr><tr><td>943.0</td><td>1798.610102865496</td></tr><tr><td>645.0</td><td>687.9853632085252</td></tr><tr><td>1061.0</td><td>1415.6211183695307</td></tr><tr><td>918.0</td><td>1641.6729306726502</td></tr><tr><td>561.0</td><td>527.5570347846425</td></tr><tr><td>814.0</td><td>1239.0013273271086</td></tr><tr><td>698.0</td><td>1198.9529314776455</td></tr><tr><td>708.0</td><td>1110.8167770712241</td></tr><tr><td>936.0</td><td>1171.8761419365826</td></tr><tr><td>720 ...

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) Evaluator
# ### Calculates statistics on our models indicating
# * goodness-of-fit, explanation of variance
# * error quantities, precision/recall/etc.
#
# ### Generates one stat at a time
# * "mode-ful" switching of stat via setter
#
# ### Why? Designed for integration and for Spark, not just us
# * In particular, answers question "Which is better?"
#
# ### RegressionEvaluator, BinaryClassificationEvaluator, ...

# %%
from pyspark.ml.evaluation import RegressionEvaluator

eval = RegressionEvaluator()
eval.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">16</span><span class="ansired">]: </span>1153.2115538900377
# </div>

# %%
eval.setMetricName("r2")
eval.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">17</span><span class="ansired">]: </span>0.9170370254054456
# </div>

# %% [markdown]
# ##![Spark Logo Tiny](https://s3-us-west-2.amazonaws.com/curriculum-release/images/105/logo_spark_tiny.png) ParamGridBuilder
#
# ### Helper to specify a grid of (hyper)params
# * Several params, chosen based on algorithm/model type
# * Several values for each param
# * Allows Spark to find/try every combination of values!
#
#
# ### Example: Parameter Grid for Tuning a Decision Tree
# | Parameter  | Test Value 1 | Test Value 2 | Test Value 3 | (etc.) |
# |------------|--------------|--------------|--------------|--------|
# | `maxDepth` | 6            | 10           | 12           | `...`  |
# | `maxBins`  | 16           | 32           | 48           | `...`  |
# | `...`      | `...`        | `...`        | `...`        | `...`  |

# %%
from pyspark.ml.tuning import *

paramGrid = ParamGridBuilder().addGrid(lr.elasticNetParam, [0.3, 0.7]).addGrid(lr.regParam, [0.01, 0.1]).build()

cv = CrossValidator().setEstimator(completePipeline).setEvaluator(eval).setEstimatorParamMaps(paramGrid).setNumFolds(3) 

cvModel = cv.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# How different was the performance across the different parameter sets?

# %%
cvModel.avgMetrics
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">36</span><span class="ansired">]: </span>
# [1130.4668061865525,
#  1130.4668061865525,
#  1130.4668061865525,
#  1130.4668061865525]
# </div>

# %%
# Given a CrossValidatorModel cvModel, how can we find out which hyperparams produced the "best" model chosen by the CrossValidator?

cvModel.getEstimatorParamMaps()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">37</span><span class="ansired">]: </span>
# [{Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;elasticNetParam&apos;, doc=&apos;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&apos;): 0.3,
#   Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;regParam&apos;, doc=&apos;regularization parameter (&gt;= 0).&apos;): 0.01},
#  {Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;elasticNetParam&apos;, doc=&apos;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&apos;): 0.3,
#   Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;regParam&apos;, doc=&apos;regularization parameter (&gt;= 0).&apos;): 0.1},
#  {Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;elasticNetParam&apos;, doc=&apos;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&apos;): 0.7,
#   Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;regParam&apos;, doc=&apos;regularization parameter (&gt;= 0).&apos;): 0.01},
#  {Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;elasticNetParam&apos;, doc=&apos;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&apos;): 0.7,
#   Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;regParam&apos;, doc=&apos;regularization parameter (&gt;= 0).&apos;): 0.1}]
# </div>

# %%
for pair in zip(cvModel.getEstimatorParamMaps(), cvModel.avgMetrics):
  print(pair)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">({Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;elasticNetParam&apos;, doc=&apos;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&apos;): 0.3, Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;regParam&apos;, doc=&apos;regularization parameter (&gt;= 0).&apos;): 0.01}, 1130.4668061865525)
# ({Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;elasticNetParam&apos;, doc=&apos;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&apos;): 0.3, Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;regParam&apos;, doc=&apos;regularization parameter (&gt;= 0).&apos;): 0.1}, 1130.4668061865525)
# ({Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;elasticNetParam&apos;, doc=&apos;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&apos;): 0.7, Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;regParam&apos;, doc=&apos;regularization parameter (&gt;= 0).&apos;): 0.01}, 1130.4668061865525)
# ({Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;elasticNetParam&apos;, doc=&apos;the ElasticNet mixing parameter, in range [0, 1]. For alpha = 0, the penalty is an L2 penalty. For alpha = 1, it is an L1 penalty.&apos;): 0.7, Param(parent=&apos;LinearRegression_24530ca9d640&apos;, name=&apos;regParam&apos;, doc=&apos;regularization parameter (&gt;= 0).&apos;): 0.1}, 1130.4668061865525)
# </div>

# %% [markdown]
# After training the CrossValidatorModel, `cvModel.bestModel` will contain a model trained on all of the training data using the best hyperparams.
#
# However, we could also train that "best model" ourselves:

# %%
lr = LinearRegression(regParam=0.1, elasticNetParam=0.7)
finalModel = completePipeline.fit(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# Run the final model against the test set

# %%
predictions = finalModel.transform(test).select("label", "prediction")
eval.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">23</span><span class="ansired">]: </span>0.9170370254054456
# </div>

# %%
eval.setMetricName("rmse")
eval.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">24</span><span class="ansired">]: </span>1153.2115538900377
# </div>

# %% [markdown]
# Have a quick look at the errors...

# %%
display(predictions.sample(False, 0.05).selectExpr("prediction-label as error"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>error</th></tr></thead><tbody><tr><td>280.1759317096614</td></tr><tr><td>300.16535980240246</td></tr><tr><td>121.95868956027073</td></tr><tr><td>-210.09312489639245</td></tr><tr><td>165.82154978507106</td></tr><tr><td>501.51317534136</td></tr><tr><td>-797.5433482866549</td></tr><tr><td>-159.19753230535275</td></tr><tr><td>282.7720712524367</td></tr><tr><td>-755.5193619743991</td></tr><tr><td>-408.7513730796195</td></tr><tr><td>228.59349388383123</td></tr><tr><td>-13.528401924099228</td></tr><tr><td>569.8356098562178</td></tr><tr><td>394.88698213290604</td></tr><tr><td>238.3880448036432</td></tr><tr><td>595.2042467574411</td></tr><tr><td>-967.1244285739838</td></tr><tr><td>-282.19220386165364</td></tr><tr><td>-256.58666983397137</td></tr><tr><td>413.17463744199176</td></tr><tr><td>42.85761086720663</td></tr><tr><td>-168.37335991444093</td></tr><tr><td>-6.999284986276052</td></tr><tr><td>486.8189829697301</td></tr><tr><td>465.81369850705096</td></tr><tr><td>495.2261344565445</td></tr><tr><td>573.360921082809</td></tr><tr><td>254.3606441252548</td></tr><tr><td>802.3581679566055</td></tr><tr><td>777.5413099855484</td></tr><tr><td>139.89253872043628</td></tr><tr><td>596.7400452609477</td></tr><tr><td>-179.7859202012778</td></tr><tr><td>-202.0075184338271</td></tr><tr><td>344.43118666007877</td></tr><tr><td>-520.3911927704517</td></tr><tr><td>-1788.1116997407457</td></tr><tr><td>41.02635466468564</td></tr><tr><td>-269.167984878908</td></tr><tr><td>-343.3552561312657</td></tr><tr><td>-151.95774952192778</td></tr><tr><td>222.00635580539642</td></tr><tr><td>-76.49494689707217</td></tr><tr><td>-322.17686577970755</td></tr><tr><td>-294.63020113614107</td></tr><tr><td>-160.46422935563612</td></tr><tr><td>-2784.140421604258</td></tr><tr><td>-1912.816786069695</td></tr><tr><td>-87.0442825322782</td></tr><tr><td>-179.0300061789295</td></tr><tr><td>-125.60261387391404</td></tr><tr><td>-756.0551434394426</td></tr><tr><td>-1379.2880751641737</td></tr><tr><td>272.3167023198198</td></tr><tr><td>231.16088277162373</td></tr><tr><td>68.76067799919042</td></tr><tr><td>587.3100468068587</td></tr><tr><td>822.4386923847171</td></tr><tr><td>418.1753013634309</td></tr><tr><td>667.5780574438979</td></tr><tr><td>414.9478990970099</td></tr><tr><td>-2043.011103117629</td></tr><tr><td>-298.64070081962456</td></tr><tr><td>-7.2591649238022455</td></tr><tr><td>-1622.6701951298064</td></tr><tr><td>-365.3991329538779</td></tr><tr><td>-1568.6118011561803</td></tr><tr><td>329.4051200623303</td></tr><tr><td>-321.10759458898013</td></tr><tr><td>86.5680771728737</td></tr><tr><td>-350.92378504458907</td></tr><tr><td>-1728.131594070147</td></tr><tr><td>428.5587805294356</td></tr><tr><td>182.29858692173207</td></tr><tr><td>492.72129052314995</td></tr><tr><td>340.78346357748546</td></tr><tr><td>139.10374820591824</td></tr><tr><td>-1226.9111965085183</td></tr><tr><td>71.07794085946034</td></tr><tr><td>-164.71339187627723</td></tr><tr><td>39.48233090301483</td></tr><tr><td>88.13212822960008</td></tr><tr><td>418.519675985224</td></tr><tr><td>647.7896248393704</td></tr><tr><td>98.17507149325661</td></tr><tr><td>7.168814318412387</td></tr><tr><td>361.43657662798273</td></tr><tr><td>-579.9136682299313</td></tr><tr><td>-243.4110813626047</td></tr><tr><td>448.697534752052</td></tr><tr><td>-331.2164111880989</td></tr><tr><td>-136.73957563945373</td></tr><tr><td>214.59857893458707</td></tr><tr><td>392.0629257716316</td></tr><tr><td>-243.84560689921716</td></tr><tr><td>-788.3659951007721</td></tr><tr><td>309.3211795708835</td></tr><tr><td>-278.4616891937393</td></tr><tr><td>251.7996859892653</td></tr><tr><td>321.50351219038635</td></tr><tr><td>892.0998559116551</td></tr><tr><td>135.0006958803633</td></tr><tr><td>513.0258743475513</td></tr><tr><td>-8.694957460291334</td></tr><tr><td>193.328619909179</td></tr><tr><td>-1708.74485294395</td></tr><tr><td>-659.7114389686278 ...

# %%
finalModel.stages[-1].coefficients
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">26</span><span class="ansired">]: </span>DenseVector([842.834, 786.0329, 741.9217, 592.904, 1895.1153, 2177.325, 2110.6092, 1402.5114, 2391.4302, 903.0278, 3588.636, 4189.3502, 2622.921, 4500.0791, 4873.2597, 4948.0735, 5298.1559, 11497.0239, -66.6421, -28.0617, -1154.8889, 58.0922, -43.1718])
# </div>

# %%
finalModel.stages[-1].intercept
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">27</span><span class="ansired">]: </span>477.8299251323677
# </div>

# %% [markdown]
# Linear regression? Really? Can't we do something a bit fancier?
# Let's take a quick look at a Gradient-Boosted Tree Regression:

# %%
from pyspark.ml.regression import GBTRegressor

gbt = GBTRegressor()
assembler = VectorAssembler(inputCols=[f + "Index" for f in categoricalFields] + ["carat", "depth", "table", "x", "y", "z"], outputCol="features")
gbtPipeline = Pipeline(stages=indexers + [assembler, gbt])

train, test = data2.randomSplit([0.75, 0.25])

gbtModel = gbtPipeline.fit(train)
predictions = gbtModel.transform(test)
eval.evaluate(predictions)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansired">Out[</span><span class="ansired">28</span><span class="ansired">]: </span>717.5823648146381
# </div>

# %% [markdown]
# Note: If you need the offical xgboost, there is a package for distributed training via Spark
# * http://dmlc.ml/2016/10/26/a-full-integration-of-xgboost-and-spark.html
# * https://xgboost.readthedocs.io/en/latest/jvm/xgboost4j_spark_tutorial.html
